# %% [markdown]
# # Самый большой заголовок
# ## Большой заголовок
# ### Средний заголовок
# #### Маленький заголовок

# %%
x = !pwd
print(x, type(x))

privet = !echo Hello dear friends

print(privet[0])

y = !ls -a F:\Downloads

for row in y:
    print(row)
# Out:
# ['/c/Users/3axap/GitHub/test'] <class 'IPython.utils.text.SList'>
# Hello dear friends
# .
# ..
# 0001-9000003-086901-0048365_21.pdf
# 1838134 AG271QG_1_0.zip
# 40379-2147735-1.zip
# 40379-2147735-2.zip
# 40379-2147735-3.zip
# 50859374868_d72012c28e_o.jpg
# 510-259-1-SM.pdf
# 5908a02764003.pdf
# Analyzing CIA Factbook Data Using SQL.ipynb
# anketa_.pdf
# anketa_2052240 (1).pdf
# anketa_2052240.pdf
# Answering Business Questions using SQL.ipynb
# aoc-agon-ag271qg-250-nits.icm
# AppleStore.csv
# appointment.pdf
# autos.csv
# bFRvULaDaMcaWm5DpcXFU8OIB0qxN0_original.xls
# BJIRTU_documents (1).pdf
# BJIRTU_documents.pdf
# broker-report-2019-12-01-2019-12-31.pdf
# broker-report-2021-01-01-2021-01-31.pdf
# broker-report-2021-02-01-2021-02-22.pdf
# broker-report-2021-03-01-2021-03-10.pdf
# BTP_RB.00.S7.50.pdf
# Calendar.ics
# certificate_covid.pdf
# chapter 1.doc
# CHECKINS.csv
# chinook.db
# chinook.zip
# chinook_store.ipynb
# Collage_majors.ipynb
# ...
